# %% [markdown]
# <a href="https://colab.research.google.com/github/yuli206/mi-proyecto/blob/main/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MI PRIMER COLAB**
#
# en este cuaderno se van a dar los primeros pasos relacionados con la programación en python
#
# > Añadir blockquote

# %% [markdown]
# ## Variables

# %% [markdown]
# ###numero entero

# %%
type(10)
# Out:
# int

# %% [markdown]
# ###numero decimal

# %%
type(10.5)
# Out:
# float

# %% [markdown]
# ###numero complejo

# %%
type(1+2j)
# Out:
# complex

# %% [markdown]
# ###cadena de caracteres

# %%
type("manzana")
# Out:
# str

# %% [markdown]
# ###lista

# %%
type([1,2,3,4,5])
# Out:
# list

# %% [markdown]
# ###tupla

# %%
type((1,2,3,4,5))
# Out:
# tuple

# %% [markdown]
# ###rango

# %%
type(range(5))
# Out:
# range

# %% [markdown]
# ###diccionario

# %%
type({"nombre":"juan","edad":"30"})
# Out:
# dict

# %% [markdown]
# ###conjuntos

# %%
type({1,2,3,4,5})
# Out:
# set

# %% [markdown]
# ## Funciones

# %% [markdown]
# ###asignacion

# %%
a=7

# %%
a
# Out:
# 7

# %%
b=8

# %%
b
# Out:
# 8

# %%
print (a,b)
# Out:
# 7 8

# %% [markdown]
# ###Operaciones basicas

# %%
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**b)
# Out:
# 15
# -1
# 56
# 0.875
# 7
# 5764801

# %% [markdown]
# ## Comparación

# %%
print(a==b)
print(a!=b)
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)

print(a is b)
# Out:
# False
# True
# False
# True
# False
# True
# False
